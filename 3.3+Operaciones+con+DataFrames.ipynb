# %% [markdown]
# <font color=Green>
#
# # **3.3 Operaciones con DataFrames**
#
# </font>

# %%
import numpy as np
import pandas as pd

# %%
d = [np.random.randint(50,size=(10))]
d
# Out:
# [array([34, 19, 27, 49, 21, 12,  9, 40, 23,  9])]

# %%
df = pd.DataFrame(d).T
df
# Out:
#     0
# 0  34
# 1  19
# 2  27
# 3  49
# 4  21
# 5  12
# 6   9
# 7  40
# 8  23
# 9   9

# %% [markdown]
# ## <font color=#003d5c>_Añadir una nueva columna_ </font>

# %%
df['nueva_col'] = 10

# %%
df['experiencia'] = 5

df
# Out:
#     0  nueva_col  experiencia
# 0  34         10            5
# 1  19         10            5
# 2  27         10            5
# 3  49         10            5
# 4  21         10            5
# 5  12         10            5
# 6   9         10            5
# 7  40         10            5
# 8  23         10            5
# 9   9         10            5

# %%
df['perdidas'] = [(i+2)*np.e for i in range(10)]

df
# Out:
#     0  nueva_col  experiencia   perdidas
# 0  34         10            5   5.436564
# 1  19         10            5   8.154845
# 2  27         10            5  10.873127
# 3  49         10            5  13.591409
# 4  21         10            5  16.309691
# 5  12         10            5  19.027973
# 6   9         10            5  21.746255
# 7  40         10            5  24.464536
# 8  23         10            5  27.182818
# 9   9         10            5  29.901100

# %%
df['columna'] = df['perdidas']*100
df
# Out:
#     0  nueva_col  experiencia   perdidas      columna
# 0  34         10            5   5.436564   543.656366
# 1  19         10            5   8.154845   815.484549
# 2  27         10            5  10.873127  1087.312731
# 3  49         10            5  13.591409  1359.140914
# 4  21         10            5  16.309691  1630.969097
# 5  12         10            5  19.027973  1902.797280
# 6   9         10            5  21.746255  2174.625463
# 7  40         10            5  24.464536  2446.453646
# 8  23         10            5  27.182818  2718.281828
# 9   9         10            5  29.901100  2990.110011

# %% [markdown]
# ## <font color=#003d5c>_Cambiar el nombre de una columna_ </font>

# %%
df.columns
# Out:
# Index([0, 'nueva_col', 'experiencia', 'perdidas', 'columna'], dtype='object')

# %%
df.columns = ['codigo_id','años_exp', 'indice', 'eficiencia','eficiencia_agregada']

df
# Out:
#    codigo_id  años_exp  indice  eficiencia  eficiencia_agregada
# 0         34        10       5    5.436564           543.656366
# 1         19        10       5    8.154845           815.484549
# 2         27        10       5   10.873127          1087.312731
# 3         49        10       5   13.591409          1359.140914
# 4         21        10       5   16.309691          1630.969097
# 5         12        10       5   19.027973          1902.797280
# 6          9        10       5   21.746255          2174.625463
# 7         40        10       5   24.464536          2446.453646
# 8         23        10       5   27.182818          2718.281828
# 9          9        10       5   29.901100          2990.110011

# %%
df['codigo_id']
# Out:
# 0    34
# 1    19
# 2    27
# 3    49
# 4    21
# 5    12
# 6     9
# 7    40
# 8    23
# 9     9
# Name: codigo_id, dtype: int64

# %% [markdown]
# ## <font color=#003d5c>_Modificar una columna_ </font>

# %%
df['indice'] = df['indice'] / 200

df
# Out:
#    codigo_id  años_exp  indice  eficiencia  eficiencia_agregada
# 0         34        10   0.025    5.436564           543.656366
# 1         19        10   0.025    8.154845           815.484549
# 2         27        10   0.025   10.873127          1087.312731
# 3         49        10   0.025   13.591409          1359.140914
# 4         21        10   0.025   16.309691          1630.969097
# 5         12        10   0.025   19.027973          1902.797280
# 6          9        10   0.025   21.746255          2174.625463
# 7         40        10   0.025   24.464536          2446.453646
# 8         23        10   0.025   27.182818          2718.281828
# 9          9        10   0.025   29.901100          2990.110011

# %% [markdown]
# ## <font color=#003d5c>_Eliminar una columna o una fila_ </font>

# %%
del df['eficiencia']

df
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         34        10   0.025           543.656366
# 1         19        10   0.025           815.484549
# 2         27        10   0.025          1087.312731
# 3         49        10   0.025          1359.140914
# 4         21        10   0.025          1630.969097
# 5         12        10   0.025          1902.797280
# 6          9        10   0.025          2174.625463
# 7         40        10   0.025          2446.453646
# 8         23        10   0.025          2718.281828
# 9          9        10   0.025          2990.110011

# %%
c = df.drop([2,3,5], axis=0) #elimino las filas 2,3,5 ya que axis = 0 indica filas
c
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         34        10   0.025           543.656366
# 1         19        10   0.025           815.484549
# 4         21        10   0.025          1630.969097
# 6          9        10   0.025          2174.625463
# 7         40        10   0.025          2446.453646
# 8         23        10   0.025          2718.281828
# 9          9        10   0.025          2990.110011

# %%
df
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         34        10   0.025           543.656366
# 1         19        10   0.025           815.484549
# 2         27        10   0.025          1087.312731
# 3         49        10   0.025          1359.140914
# 4         21        10   0.025          1630.969097
# 5         12        10   0.025          1902.797280
# 6          9        10   0.025          2174.625463
# 7         40        10   0.025          2446.453646
# 8         23        10   0.025          2718.281828
# 9          9        10   0.025          2990.110011

# %%
df.drop(['eficiencia_agregada'], axis=1, inplace =  True) #eliminar la columna y reemplazar el df

df.head()
# Out:
#    codigo_id  años_exp  indice
# 0         34        10   0.025
# 1         19        10   0.025
# 2         27        10   0.025
# 3         49        10   0.025
# 4         21        10   0.025

# %%
df
# Out:
#    codigo_id  años_exp  indice
# 0         34        10   0.025
# 1         19        10   0.025
# 2         27        10   0.025
# 3         49        10   0.025
# 4         21        10   0.025
# 5         12        10   0.025
# 6          9        10   0.025
# 7         40        10   0.025
# 8         23        10   0.025
# 9          9        10   0.025

# %% [markdown]
# ## <font color=#003d5c>_Modificar el índice_ </font>

# %%
i = ['a','b','c','d','e','f','g','h','i','j']

df.index = i #cambia los indices del dataframe

df

# %%
df["codigo_id"].mean()
# Out:
# 24.3

# %%
df["codigo_id"].sum()
# Out:
# 243

# %%
df["codigo_id"].min()
# Out:
# 9

# %%
df["codigo_id"].max()
# Out:
# 49

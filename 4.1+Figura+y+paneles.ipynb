# %% [markdown]
# <font color=Green>
#
# # **4.1 Figura y paneles**
#
# </font>
#
# ## <font color=#003d5c>Matplotlib</font>
#
# ### Hacer gráficos y visualizaciones es una de las tareas más importantes a la hora de procesar y analízar datos. Puede formar parte del análisis exploratorio de datos para identificar valores extremos (outliers) o como medio de comunicación de resultados.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <img src= "https://files.realpython.com/media/fig_map.bc8c7cabd823.png">

# %%
fig, panel = plt.subplots()

x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)

panel.plot(x, y)

# %% [markdown]
# ### Podemos crear una figura con varios paneles

# %%
# Crea la figura con dos paneles horizontales
fig, (pan_1, pan_2) = plt.subplots(2, 1)

# Figura 1
x1 = np.linspace(0, 4 * np.pi, 100)
y1 = np.sin(x1)

pan_1.plot(x1, y1)

# Figura 2
x2 = np.linspace(0, 4 * np.pi, 100)
y2 = np.cos(x2)

pan_2.plot(x2, y2)


# Guardar la figura
plt.savefig(r'C:\Users\Franco\Udemy\sin_cos.png')

# %%
# Crea la figura con dos paneles verticales
fig, (pan_1, pan_2) = plt.subplots(1, 2, constrained_layout=True) #1 fila, 2 columnas, constrained_layout=True separa las fig.

# Figura 1
x1 = np.linspace(0, 4 * np.pi, 100)
y1 = np.sin(x1)

pan_1.plot(x1, y1)

# Figura 2
x2 = np.linspace(0, 4 * np.pi, 100)
y2 = np.cos(x2)

pan_2.plot(x2, y2)


plt.savefig(r'C:\Users\Franco\Udemy\sin_cos_vertical.png')

# %%
fig, ((pan_1, pan_2), (pan_3, pan_4)) = plt.subplots(2, 2,constrained_layout=True) #2 filas y 2 columnas

x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)


pan_1.plot(x, y)

pan_2.plot(x, y**2)

pan_3.plot(x, -y)

pan_4.plot(x, -y**2)

for ax in fig.get_axes(): #get.axes toma al panel como elemento
    ax.set(xlabel='x-label', ylabel='y-label')

# %% [markdown]
# ### El parámetro _sharex_ nos permite indicar que los paneles comparten el eje X
# ### El parámetro _sharey_ nos permite indicar que los paneles comparten el eje Y

# %%
fig, (pan_1, pan_2) = plt.subplots(2, sharex=True) #los dos paneles comparten eje X

x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)

pan_1.plot(x, y, 'tab:orange')

pan_2.plot(x + 1, -y, 'green')

# %%
fig, (pan_1, pan_2) = plt.subplots(1,2, sharey=True) # para compartir eje y hay que ubicarlo horizontalmente

x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)

pan_1.plot(x, y)

pan_2.plot(-x, y+1)

# %%
fig, paneles = plt.subplots(2, 2, sharex='col', sharey='row')

(pan_1, pan_2), (pan_3, pan_4) = paneles

pan_1.plot(x, y)

pan_2.plot(x, y**2, 'tab:orange')

pan_3.plot(x + 1, -y, 'tab:green')

pan_4.plot(x + 2, -y**2, 'tab:red')

# %% [markdown]
# ## <font color=#003d5c> _.twinx()_ </font>
#
# ### Este método nos permite graficar ambas funciones en un mismo panel.

# %%
fig, pan_1 = plt.subplots(1, 1)

pan_2 = pan_1.twinx()


x1 = np.linspace(0, 4 * np.pi, 100)
y1 = np.sin(x1)

pan_1.plot(x1, y1, 'y') #'y' es la inicial del color de la linea


x2 = np.linspace(0, 4 * np.pi, 100)
y2 = np.cos(x2)

pan_2.plot(x2, y2, 'r') #'r' es la inicial del color de la linea del grafico red


plt.savefig('sin_cos_2.png')
